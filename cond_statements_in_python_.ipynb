# %%
"""1. Program to find the biggest of two numbers:
Input:
10
20
Output:
20
"""
a,b=map(int,input("enter numbers: ").split())
if a > b:
     print(a)
else:
     print(b)
# Out:
# enter numbers: 10 20
# 20

# %%
"""2. Program to find the eligibility for voting by taking age as an input.
Input:
25
Output:
Eligible
"""
age=int(input())
if age > 18:
 print("Eligible")
else:
 print("not eligible")
# Out:
# 13
# not eligible

# %%
"""3. Program to find the given character is vowel or consonant?
Input:
A
Output:
Vowel
Input:
S
Output:
Consonant
"""
char=input()
if char.lower() in "aeiou":
   print("vowel")
elif char.lower() not in "aeiou":
   print("consonant")
# Out:
# a
# vowel

# %%
"""
4. Program to input angles of a triangle and check whether triangle is valid or not.
Input:
2
3
4
Output:
Valid
"""
a,b,c=map(int,input().split())
if a + b > c and b + c > a and c + a > b:
  print("Valid")
else:
  print("Invalid")
# Out:
# 10 20 30
# Invalid

# %%
"""
5. Program to check whether a triangle is equilatoral, Isosceles or Scalence.
Input:
2
3
4
Output:
Scalence
"""
a,b,c=map(int,input().split())
if a == b == c:
  print("Equilateral")
elif a == b or b == c or c == a:
  print("Isosceles")
else:
  print("Scalene")
# Out:
# 10 20 30
# Scalence

# %%
"""6. Write a program find who is best hero based on given input?
Input:  Chiru 67 52 27
	    Balayya 45 33 26
Note: 1 hit movie= 10 points, 1 average movie=5, a flop movie= -5
Input format is: Hero_Name Hit_Movies Avg_Movies Flop_Movies.
"""
name,hit,avg,flop=input().split()
name2,hit2,avg2,flop2=input().split()
hit=int(hit)
hit2=int(hit2)
avg=int(avg)
avg2=int(avg2)
flop=int(flop)
flop2=int(flop2)
hit=hit*10
avg=avg*5
flop=flop*-5
hit2=hit2*10
avg2=avg2*5
flop2=flop2*-5
total=hit+avg+flop
total2=hit2+avg2+flop2
if total>total2:
  print(name)
else:
  print(name2)
# Out:
# Chiru 67 52 27
# balayya 34 45 10
# Chiru

# %%
"""
 Write a program to display the given digit(1 to 3) in words as follows
		Input:	9
		Output: Nine"""
digit=int(input())
match digit:
  case 1 : print("one")
  case 2 : print("two")
  case 3: print("three")
  case _ :print("invalid")
# Out:
# 5
# invalid

# %%
"""

8. Write a program to display Colour name by taking input as colour code.
For example
			Y -> Yellow
			R -> Red
			G -> Green
			B -> Blue
			V -> Violet
			O -> Orange
			I -> Indigo
		Input:	R
	Output: Red"""
color_code = input()

match color_code.upper():

  case 'Y': print('Yellow')
  case 'R': print('Red')
  case 'G': print('Green')
  case 'B': print('Blue')
  case 'V': print('Violet')
  case 'O': print('Orange')
  case 'I': print('Indigo')
  case _: print('Invalid Color Code')
# Out:
# a
# Invalid Color Code

# %%
"""
Write a program to read temperature in centigrade and display a suitable message according to temperature state below:
		Temp < 0 then Freezing weather
		Temp 0-10 then Very Cold weather
		Temp 10-20 then Cold weather
		Temp 20-30 then Normal in Temp
		Temp 30-40 then Its Hot
		Temp >=40 then Its Very Hot
"""
temp = int(input("Enter temperature in Centigrade: "))

if temp < 0:
  print("Freezing weather")
elif temp >= 0 and temp < 10:
  print("Very Cold weather")
elif temp >= 10 and temp < 20:
  print("Cold weather")
elif temp >= 20 and temp < 30:
  print("Normal in Temp")
elif temp >= 30 and temp < 40:
  print("Its Hot")
else:
  print("Its Very Hot")
# Out:
# Enter temperature in Centigrade: 30
# Its Hot

# %%
"""
 Write a program to display season by taking the input as month.
		Assume: 3, 4, 5 	– Summer
		6, 7, 8, 9 		– Rainy
		10, 11, 12, 1, 2 	-- Winter
		Input:	9
		Output: Rainy"""
month = int(input("Enter the month (1-12): "))

if month in [3, 4, 5]:
  print("Summer")
elif month in [6, 7, 8, 9]:
  print("Rainy")
elif month in [10, 11, 12, 1, 2]:
  print("Winter")
else:
  print("Invalid month input. Please enter a number between 1 and 12.")
# Out:
# Enter the month (1-12): 12
# Winter

# %%
#program to find the roots of the quadratic equation
import cmath

# 1. Take coefficients as input from the user
a = float(input("Enter coefficient a: "))
b = float(input("Enter coefficient b: "))
c = float(input("Enter coefficient c: "))

# 2. Check if it's a valid quadratic equation
if a == 0:
    print("The value of 'a' cannot be zero in a quadratic equation.")
else:
    # 3. Calculate the discriminant
    d = (b**2) - (4*a*c)

    # 4. Find the two roots using the quadratic formula
    root1 = (-b - cmath.sqrt(d)) / (2*a)
    root2 = (-b + cmath.sqrt(d)) / (2*a)
    print(f"Root 1: {root1}")
    print(f"Root 2: {root2}")
# Out:
# Enter coefficient a: 2
# Enter coefficient b: 3
# Enter coefficient c: 4
# Root 1: (-0.75-1.1989578808281798j)
# Root 2: (-0.75+1.1989578808281798j)

# %%
basic = float(input())

if basic <= 10000:
    hra = basic * 20 / 100
    da = basic * 80 / 100

elif basic <= 20000:
    hra = basic * 25 / 100
    da = basic * 90 / 100

else:
    hra = basic * 30 / 100
    da = basic * 95 / 100

gross = basic + hra + da

print(gross)
# Out:
# 20000
# 43000.0

# %%
"""
Program to input electricity unit charges and calculate total electricity bill according to the given condition:
for first 50 units Rs - 0.50/unit
for next 100 units Rs - 0.75/unit
for next 100 units Rs - 1.20/unit
for unit above 250 Rs - 1.50/unit
An additional surcharge of 20% is added to the bill."""
units=float(input("enter units: "))
if units<50:
  bill=units*0.50
elif units<150:
  bill=50*0.50+(units-50)*0.75
elif units<250:
  bill=50*0.50+100*0.75+(units-150)*1.20
else:
  bill=50*0.50+100*0.75+100*1.20+(units-250)*1.50
bill=bill+bill*20/100
print(bill)
# Out:
# enter units: 150
# 120.0
